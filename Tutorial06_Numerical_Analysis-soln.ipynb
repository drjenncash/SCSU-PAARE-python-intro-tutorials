# %% [markdown]
# # Tutorial 6: Numerical Data Analysis with NumPy (Solutions
#
# This notebook accompanies the tutorial and provides possible solutions to the practices and exercises. As always, there are multiple ways to solve these problems that are correct.
#
#
# This tutorial was compiled for the PAARE project at South Carolina State University in partnership with Clemson University and the University of the Virgin Islands and funded by NSF. (NSF grant AST  2319415)
#
# * Originally posted
#   * JCash June 25, 2025
# * Last modified:
#   * JCash June 22, 2026

# %% [markdown]
# ### Imports needed
#
# Since NumPy is not built into Python, we need import the package to use the functions. NumPy is so commonly used that the shortened alias import statement of `import numpy as np` is standard.
#
# As a reminder, you only need to import the package once when you open a notebook, but it doesn't hurt to run that command multiple times in the notebook. If you save your notebook and come back to it later or interrupt the kernel, you will need to reimport the package.

# %%
import numpy as np

# %% [markdown]
# ## 1.0) NumPy math operations

# %% [markdown]
# ---
# **Practice**
#
# Astronomers often work in angles measured in degrees while NumPy uses the standard of radians.
#
# Tasks:
# * Create a variable called ang_deg and assign the value of 45
# * Convert the value to radians using  np.deg2rad().
# * Calculate the sine of the angle using np.sin().
# * Use round() to round the result to 3 decimal places.
# * Print the angle in degrees, radians, and the sine value.

# %%
#insert your code here
ang_deg = 45
ang_rad = np.deg2rad(ang_deg)
sine_val = np.round(np.sin(ang_rad),3)
print('The angle is:',ang_deg,'degrees or ', np.round(ang_rad,4),'radians')
print('The sine of the angle is',sine_val)
# Out:
# The angle is: 45 degrees or  0.7854 radians
# The sine of the angle is 0.707

# %% [markdown]
# ## 2.0) Creating NumPy arrays
#
# NumPy is particularly powerful due to its ability to deal with arrays of data instead of just single values.
#
# We have explored basic array creation in previous tutorials, but show some additional methods here.

# %% [markdown]
# **Practice**
#
# Here we are going to practice creating some arrays for stellar temperatures.
#
# Create a NumPy array containing the temperatures of five stars:
# 3000, 4500, 6000, 7500, 9000
#
# * Create the array manually.
# * Print the array
# * Print its shape.
# * Create a second array using np.ones() that has the same number of elements.
# * Create a third array using np.arange() that starts at 3000 and ends at 9000 in steps of 1500.
# * Combine the temperature array and the ones array into a 2D array.
# * Print the shape of the resulting 2D array.
# * How many dimensions does the final array have

# %%
#insert your code here

# %% [markdown]
# ## 3.0) NumPy Array Math

# %% [markdown]
# **Practice**
#
# * Create the following arrays:
#    * temperatures = np.array([5000, 6000, 7000])
#    * radii = np.array([1.0, 1.2, 1.5])
#
# * calculate a result using both of those quantities
#    * result = radius^2 * temperature^4
#
# * print the result

# %% [markdown]
# ### 3.3) Statistical functions

# %% [markdown]
# **Practice**
#
# A group of stars has the following temperatures:
#
# temperatures = np.array([3500, 4500, 5500, 6500, 7500])
#
#
# * Determine:
#     * the mean temperature
#     * the minimum temperature
#     * the maximum temperature
# * Print the results.

# %%
#insert your code here

# %% [markdown]
# ### 3.4) Boolean Operations

# %% [markdown]
# **Practice**
#
# Consider the following list of temperatures.
# temperatures = np.array([3500, 4500, 5500, 6500, 7500])
#
# * Create a Boolean array that identifies stars hotter than 5000 K.
# * Print the Boolean array.
# * Use the Boolean array to create a new array containing only the hotter stars.
# * Determine how many stars are in the filtered array.

# %% [markdown]
# ## 4.0) NumPy Array Manipulation

# %%
#Add code here

# %% [markdown]
# ## 5.0) Very useful NumPy functions and methods
#
# Ones that look at whole array:
#
# - sort()
# - count()
# - unique()
# - where()

# %% [markdown]
# ---
# ---
#
# # Assignments
#
#
# These exercises focus on the use of the NumPy functions

# %% [markdown]
# ---
# ## Exercise 1) Creating and Organizing Stellar Data (Introductory)
#
# Astronomers often work with catalogs containing measurements of many stars. In this exercise, you will create and inspect several NumPy arrays.
#
# **Task**
#
# Create a NumPy array containing the temperatures (K) of five stars:
#
# [3500, 5000, 6500, 8000, 9500]
#
# Create a second NumPy array containing the radii (in solar radii) of the same stars:
#
# [0.5, 0.9, 1.2, 2.0, 3.5]
#
# * Determine the shape, number of dimensions, and data type of each array.
# * Create a 2D array containing both the temperatures and radii.
# * Determine the shape of the new 2D array.
# * Transpose the array so that each row represents a star.
# * Verify the shape of the transposed array.
#
# Questions
# * How many stars are represented in the final array?
# * How many properties are stored for each star?

# %% [markdown]
# ---
# ## Exercise 2) Investigating Stellar Properties (Moderate)
#
# A simplified stellar luminosity relationship can be written as:
#
# ```python
# luminosity_factor = radius**2 * temperature**4
# ```
#
# where the radius is given in solar radii and the temperature is given in Kelvin.
#
# ### Task
#
# Create NumPy arrays containing:
#
# ```python
# temperatures = [3500, 4500, 5500, 6500, 7500, 8500]
# radii = [0.4, 0.8, 1.0, 1.3, 2.0, 3.0]
# ```
#
# 1. Calculate the luminosity factor for each star.
# 2. Determine:
#
#    * the minimum luminosity factor
#    * the maximum luminosity factor
#    * the mean luminosity factor
# 3. Identify the star with the largest luminosity factor.
# 4. Create a new array containing only stars with temperatures greater than 6000 K.
# 5. Calculate the mean luminosity factor of this hotter-star subset.
#
# ### Discussion
#
# How does increasing temperature affect the luminosity factor compared to increasing radius?

# %% [markdown]
# ---
# ## Exercise 3: Finding Candidate Blue Stars (Challenging)
#
# A survey has measured the temperatures of 100 stars.
#
# ### Task
#
# Use NumPy to create an array of 100 random temperatures ranging from 3000 K to 12000 K.
#
# 1. Determine:
#
#    * the minimum temperature
#    * the maximum temperature
#    * the mean temperature
# 2. Create a Boolean mask that identifies stars hotter than 7500 K.
# 3. Use the mask to create a filtered array containing only the hotter stars.
# 4. Determine:
#
#    * how many stars meet the criterion
#    * the mean temperature of the selected stars
#    * the hottest selected star
# 5. Sort the filtered array from coolest to hottest.
# 6. Determine the number of unique temperatures present in the filtered array.

# %% [markdown]
# ### Challenge Extension
#
# Suppose some measurements failed and should be represented by `np.nan`.
#
# Replace five randomly selected values in the original array with `np.nan`.
#
# Investigate how the presence of `np.nan` affects statistical calculations and determine an appropriate NumPy function to handle missing values.

# %% [markdown]
# ----
# ## Additional exercises with data files
#
# Once you complete the next tutorial on reading data files, we can do a lot more interesting stuff with the data in those files.
